# %%
import pandas as pd
import oracledb
from sqlalchemy import create_engine
oracle_conn = create_engine("oracle+oracledb://system:admin@localhost:1521/xe")
pd.read_sql("""select * from employees""",oracle_conn)
# Out:
#     empid          empname department   salary  managerid joiningdate
# 0       1     Anjali Mehta      Sales  68000.0        NaN  2020-03-15
# 1       2      Rahul Singh  Marketing   1000.0        1.0  2019-06-01
# 2       3        Meera Das         HR  50000.0        1.0  2021-01-20
# 3       4       Vikram Rao         IT  85000.0        2.0  2018-07-10
# 4       5       Priya Iyer      Sales  60000.0        2.0  2022-02-11
# 5       6       Arjun Nair         IT  95000.0        4.0  2017-09-05
# 6       7     Suresh Patil    Finance  78000.0        1.0  2019-12-01
# 7       8      Neha Kapoor  Marketing  67000.0        2.0  2021-03-22
# 8       9       Amit Verma      Sales  72000.0        5.0  2018-11-15
# 9      10      Kavya Reddy         IT  88000.0        4.0  2020-08-17
# 10     11      Rohan Gupta    Finance  64000.0        7.0  2021-06-05
# 11     12     Pooja Sharma         HR  55000.0        3.0  2022-07-11
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NoSuchModuleError                         Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 oracle_conn = create_engine("oracle+oracledb://system:admin@localhost:1521/xe")
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File C:\Python310\lib\site-packages\sqlalchemy\util\deprecations.py:375, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     368     if m in kwargs:
#     369         _warn_with_version(
#     370             messages[m],
#     371             versions[m],
#     372             version_warnings[m],
#     373             stacklevel=3,
#     374         )
# --> 375 return fn(*args, **kwargs)
#
# File C:\Python310\lib\site-packages\sqlalchemy\engine\create.py:518, in create_engine(url, **kwargs)
#     514 u = _url.make_url(url)
#     516 u, plugins, kwargs = u._instantiate_plugins(kwargs)
# ...
