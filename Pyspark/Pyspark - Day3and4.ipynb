# %%
import pandas as pd
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Pyspark Day 3").getOrCreate()
from pyspark.sql import functions as F
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Input In [30], in <cell line: 3>()
#       1 import pandas as pd
#       2 from pyspark.sql import SparkSession
# ----> 3 spark = SparkSession.builder.appName("Pyspark Day 3").getOrCreate()
#       4 from pyspark.sql import functions as F
#
# File C:\Python310\lib\site-packages\pyspark\sql\session.py:561, in SparkSession.Builder.getOrCreate(self)
#     559     session = SparkSession(sc, options=self._options)
#     560 else:
# --> 561     module = SparkSession._get_j_spark_session_module(session._jvm)
#     562     module.applyModifiableSettings(session._jsparkSession, self._options)
#     563 return session
#
# File C:\Python310\lib\site-packages\pyspark\sql\session.py:672, in SparkSession._get_j_spark_session_module(jvm)
#     670 @staticmethod
#     671 def _get_j_spark_session_module(jvm: "JVMView") -> "JavaObject":
# --> 672     return getattr(getattr(jvm, "org.apache.spark.sql.classic.SparkSession$"), "MODULE$")
#
# File C:\Python310\lib\site-packages\py4j\java_gateway.py:1752, in JVMView.__getattr__(self, name)
#    1749 if name == UserHelpAutoCompletion.KEY:
#    1750     return UserHelpAutoCompletion()
# -> 1752 answer = self._gateway_client.send_command(
#    1753     proto.REFLECTION_COMMAND_NAME +
#    1754     proto.REFL_GET_UNKNOWN_SUB_COMMAND_NAME + name + "\n" + self._id +
#    1755     "\n" + proto.END_COMMAND_PART)
#    1756 if answer == proto.SUCCESS_PACKAGE:
#    1757     return JavaPackage(name, self._gateway_client, jvm_id=self._id)
#
# File C:\Python310\lib\site-packages\py4j\java_gateway.py:1036, in GatewayClient.send_command(self, command, retry, binary)
#    1015 def send_command(self, command, retry=True, binary=False):
#    1016     """Sends a command to the JVM. This method is not intended to be
#    1017        called directly by Py4J users. It is usually called by
#    1018        :class:`JavaMember` instances.
#    (...)
#    1034      if `binary` is `True`.
#    1035     """
# -> 1036     connection = self._get_connection()
#    1037     try:
#    1038         response = connection.send_command(command)
#
# File C:\Python310\lib\site-packages\py4j\clientserver.py:284, in JavaClient._get_connection(self)
#     281     pass
#     283 if connection is None or connection.socket is None:
# --> 284     connection = self._create_new_connection()
#     285 return connection
#
# File C:\Python310\lib\site-packages\py4j\clientserver.py:291, in JavaClient._create_new_connection(self)
#     287 def _create_new_connection(self):
#     288     connection = ClientServerConnection(
#     289         self.java_parameters, self.python_parameters,
#     290         self.gateway_property, self)
# --> 291     connection.connect_to_java_server()
#     292     self.set_thread_connection(connection)
#     293     return connection
#
# File C:\Python310\lib\site-packages\py4j\clientserver.py:438, in ClientServerConnection.connect_to_java_server(self)
#     435 if self.ssl_context:
#     436     self.socket = self.ssl_context.wrap_socket(
#     437         self.socket, server_hostname=self.java_address)
# --> 438 self.socket.connect((self.java_address, self.java_port))
#     439 self.stream = self.socket.makefile("rb")
#     440 self.is_connected = True
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it

# %%
# Filtering and condition (Where)
# filter the data for depnto = 10 
df = spark.read.csv("emp.csv",header=True)
df_filtered = df.filter(df.deptno == 10)
df_filtered.show()

df.show()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Input In [29], in <cell line: 3>()
#       1 # Filtering and condition (Where)
#       2 # filter the data for depnto = 10
# ----> 3 df = spark.read.csv("emp.csv",header=True)
#       4 df_filtered = df.filter(df.deptno == 10)
#       5 df_filtered.show()
#
# File C:\Python310\lib\site-packages\pyspark\sql\session.py:1898, in SparkSession.read(self)
#    1861 @property
#    1862 def read(self) -> DataFrameReader:
#    1863     """
#    1864     Returns a :class:`DataFrameReader` that can be used to read data
#    1865     in as a :class:`DataFrame`.
#    (...)
#    1896     +---+------------+
#    1897     """
# -> 1898     return DataFrameReader(self)
#
# File C:\Python310\lib\site-packages\pyspark\sql\readwriter.py:69, in DataFrameReader.__init__(self, spark)
#      68 def __init__(self, spark: "SparkSession"):
# ---> 69     self._jreader = spark._jsparkSession.read()
#      70     self._spark = spark
#
# File C:\Python310\lib\site-packages\py4j\java_gateway.py:1361, in JavaMember.__call__(self, *args)
#    1354 args_command, temp_args = self._build_args(*args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
#    1359     proto.END_COMMAND_PART
# -> 1361 answer = self.gateway_client.send_command(command)
#    1362 return_value = get_return_value(
#    1363     answer, self.gateway_client, self.target_id, self.name)
#    1365 for temp_arg in temp_args:
#
# File C:\Python310\lib\site-packages\py4j\java_gateway.py:1036, in GatewayClient.send_command(self, command, retry, binary)
#    1015 def send_command(self, command, retry=True, binary=False):
#    1016     """Sends a command to the JVM. This method is not intended to be
#    1017        called directly by Py4J users. It is usually called by
#    1018        :class:`JavaMember` instances.
#    (...)
#    1034      if `binary` is `True`.
#    1035     """
# -> 1036     connection = self._get_connection()
#    1037     try:
#    1038         response = connection.send_command(command)
#
# File C:\Python310\lib\site-packages\py4j\clientserver.py:284, in JavaClient._get_connection(self)
#     281     pass
#     283 if connection is None or connection.socket is None:
# --> 284     connection = self._create_new_connection()
#     285 return connection
#
# File C:\Python310\lib\site-packages\py4j\clientserver.py:291, in JavaClient._create_new_connection(self)
#     287 def _create_new_connection(self):
#     288     connection = ClientServerConnection(
#     289         self.java_parameters, self.python_parameters,
#     290         self.gateway_property, self)
# --> 291     connection.connect_to_java_server()
#     292     self.set_thread_connection(connection)
#     293     return connection
#
# File C:\Python310\lib\site-packages\py4j\clientserver.py:438, in ClientServerConnection.connect_to_java_server(self)
#     435 if self.ssl_context:
#     436     self.socket = self.ssl_context.wrap_socket(
#     437         self.socket, server_hostname=self.java_address)
# --> 438 self.socket.connect((self.java_address, self.java_port))
#     439 self.stream = self.socket.makefile("rb")
#     440 self.is_connected = True
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it

# %%
# Filtering and condition (Where)
# filter the data for depnto = 10 and salary > 1000
df = spark.read.csv("emp.csv",header=True)
df_filtered = df.filter((df.deptno == 10) & (df.salary > 1000))
df_filtered.show()
# Out:
# +---+------+------+------+----------+
# |eno| ename|salary|deptno|       doj|
# +---+------+------+------+----------+
# |  5|  Jade|  2000|    10|2021-02-10|
# | 13|Simran|  1500|    10|2019-12-19|
# | 16| Rahul|  1200|    10|2016-03-28|
# | 18|Rakesh|  1800|    10|2020-09-04|
# | 21| Sneha|  2700|    10|2022-12-14|
# | 24| Vinod|  1800|    10|2016-07-30|
# | 26| Harsh|  1600|    10|2021-09-25|
# | 28| Mohan|  1300|    10|2015-04-17|
# | 30|Suresh|  1100|    10|2018-09-09|
# | 32|  Ajay|  2100|    10|2020-06-26|
# | 35| Seema|  3000|    10|2021-10-15|
# | 38|  Alok|  2700|    10|2019-03-02|
# | 42| Tarun|  2200|    10|2021-01-09|
# | 44| Ashok|  1900|    10|2016-06-08|
# +---+------+------+------+----------+

# %%
# filter the data for depnto = 10 and depnto = 20
df = spark.read.csv("emp.csv",header=True)
df_filtered = df.filter((df.deptno == 10) | (df.deptno == 20))
df_filtered.show()
# Out:
# +---+------+------+------+----------+
# |eno| ename|salary|deptno|       doj|
# +---+------+------+------+----------+
# | 10| Amber|  1000|    10|2018-05-14|
# |  2|  Amar|  1000|    10|2017-03-22|
# |  8| Sagar|  1000|    20|2020-11-30|
# |  4|Thomas|  1000|    10|2019-08-18|
# |  5|  Jade|  2000|    10|2021-02-10|
# |  6| Smith|  1000|    10|2016-12-01|
# |  7|Robert|  3000|    20|2023-06-25|
# | 12| Karan|  2200|    20|2018-06-16|
# | 13|Simran|  1500|    10|2019-12-19|
# | 15|  Neha|  1700|    20|2021-07-22|
# | 16| Rahul|  1200|    10|2016-03-28|
# | 18|Rakesh|  1800|    10|2020-09-04|
# | 19|Monica|  2500|    20|2023-08-07|
# | 21| Sneha|  2700|    10|2022-12-14|
# | 22| David|  1000|    20|2017-02-17|
# | 24| Vinod|  1800|    10|2016-07-30|
# | 25| Meena|  2000|    20|2020-03-13|
# | 26| Harsh|  1600|    10|2021-09-25|
# | 28| Mohan|  1300|    10|2015-04-17|
# | 29| Priya|  1200|    20|2023-02-11|
# +---+------+------+------+----------+
# only showing top 20 rows

# %%
# filter the data for depnto = 10 and depnto = 20 using in condition
df = spark.read.csv("emp.csv",header=True)
df_filtered = df.filter((df.deptno.isin(10,20)))
df_filtered.show()
# Out:
# +---+------+------+------+----------+
# |eno| ename|salary|deptno|       doj|
# +---+------+------+------+----------+
# | 10| Amber|  1000|    10|2018-05-14|
# |  2|  Amar|  1000|    10|2017-03-22|
# |  8| Sagar|  1000|    20|2020-11-30|
# |  4|Thomas|  1000|    10|2019-08-18|
# |  5|  Jade|  2000|    10|2021-02-10|
# |  6| Smith|  1000|    10|2016-12-01|
# |  7|Robert|  3000|    20|2023-06-25|
# | 12| Karan|  2200|    20|2018-06-16|
# | 13|Simran|  1500|    10|2019-12-19|
# | 15|  Neha|  1700|    20|2021-07-22|
# | 16| Rahul|  1200|    10|2016-03-28|
# | 18|Rakesh|  1800|    10|2020-09-04|
# | 19|Monica|  2500|    20|2023-08-07|
# | 21| Sneha|  2700|    10|2022-12-14|
# | 22| David|  1000|    20|2017-02-17|
# | 24| Vinod|  1800|    10|2016-07-30|
# | 25| Meena|  2000|    20|2020-03-13|
# | 26| Harsh|  1600|    10|2021-09-25|
# | 28| Mohan|  1300|    10|2015-04-17|
# | 29| Priya|  1200|    20|2023-02-11|
# +---+------+------+------+----------+
# only showing top 20 rows

# %%
df.show()
# Out:
# +---+------+------+------+----------+
# |eno| ename|salary|deptno|       doj|
# +---+------+------+------+----------+
# | 10| Amber|  1000|    10|2018-05-14|
# |  2|  Amar|  1000|    10|2017-03-22|
# |  8| Sagar|  1000|    20|2020-11-30|
# |  4|Thomas|  1000|    10|2019-08-18|
# |  5|  Jade|  2000|    10|2021-02-10|
# |  6| Smith|  1000|    10|2016-12-01|
# |  7|Robert|  3000|    20|2023-06-25|
# |  3|  Nick|  1000|    30|2015-09-15|
# |  9| Naman|  4000|    30|2020-01-20|
# |  1| Vikas|  1000|    30|2017-10-03|
# | 11|Dennis| 41000|    30|2024-01-05|
# | 12| Karan|  2200|    20|2018-06-16|
# | 13|Simran|  1500|    10|2019-12-19|
# | 14|  Amit|  2000|    30|2022-04-09|
# | 15|  Neha|  1700|    20|2021-07-22|
# | 16| Rahul|  1200|    10|2016-03-28|
# | 17| Divya|  3000|    30|2015-11-11|
# | 18|Rakesh|  1800|    10|2020-09-04|
# | 19|Monica|  2500|    20|2023-08-07|
# | 20|  John|  2300|    30|2018-10-29|
# +---+------+------+------+----------+
# only showing top 20 rows

# %%
# Group by ( Grouping data )
df = spark.read.json("emp_details.json")

# %%
# Get the total salary per deptid
df.groupBy('deptid').agg(F.sum("salary").alias("Total_salary")).show()
# Out:
# +------+------------+
# |deptid|Total_salary|
# +------+------------+
# |    50|      156000|
# |    10|      272000|
# |    30|      237000|
# |    20|      227000|
# |    60|       66000|
# |    40|      195000|
# +------+------------+

# %%
# Get the total salary based on each deptid and city
df.groupBy('city','deptid').agg(F.sum("salary").alias("Total_salary")).show()
# Out:
# +---------+------+------------+
# |     city|deptid|Total_salary|
# +---------+------+------------+
# |  Chennai|    40|       65000|
# |   Mumbai|    20|       60000|
# |Bengaluru|    50|       48000|
# |     Pune|    20|       49000|
# |    Delhi|    20|       62000|
# |   Mumbai|    30|       59000|
# |Hyderabad|    50|       61000|
# |Ahmedabad|    30|       61000|
# |Bengaluru|    10|      110000|
# |  Kolkata|    10|      107000|
# |  Chennai|    60|       66000|
# |   Jaipur|    50|       47000|
# |     Pune|    30|       57000|
# |    Delhi|    40|      130000|
# |Hyderabad|    30|       60000|
# |    Surat|    20|       56000|
# |   Mumbai|    10|       55000|
# +---------+------+------------+

# %%
# Get the min,max.avg,total salary from each city
df_ans = df.groupBy('city').agg(F.min("salary").alias("min_salary"),F.max("salary").alias("max"),F.avg("salary").alias("avg_salary")
                      ,F.sum("salary").alias("total_salary"),F.count("salary").alias("total_employees"))
df_ans.show()
# Out:
# +---------+----------+-----+------------------+------------+---------------+
# |     city|min_salary|  max|        avg_salary|total_salary|total_employees|
# +---------+----------+-----+------------------+------------+---------------+
# |  Chennai|     65000|66000|           65500.0|      131000|              2|
# |   Mumbai|     55000|60000|           58000.0|      174000|              3|
# |Ahmedabad|     61000|61000|           61000.0|       61000|              1|
# |  Kolkata|     53000|54000|           53500.0|      107000|              2|
# |    Surat|     56000|56000|           56000.0|       56000|              1|
# |     Pune|     49000|57000|           53000.0|      106000|              2|
# |    Delhi|     62000|67000|           64000.0|      192000|              3|
# |Bengaluru|     48000|58000|52666.666666666664|      158000|              3|
# |Hyderabad|     60000|61000|           60500.0|      121000|              2|
# |   Jaipur|     47000|47000|           47000.0|       47000|              1|
# +---------+----------+-----+------------------+------------+---------------+

# %%
# Filter before gouping and order in ascending order of deptid

df_filter = df.filter(df.salary <55000)
#df_filter.show()
df_grouped = df_filter.groupby('deptid').agg(F.count('eno').alias('total_count'))
df_grouped.orderBy(df_grouped.deptid.asc()).show()
# Out:
# +------+-----------+
# |deptid|total_count|
# +------+-----------+
# |    10|          3|
# |    20|          1|
# |    50|          2|
# +------+-----------+

# %%
# filtering the grouped data ( HAVING)
# get me all the deptid where total_salary in the department is more than 250000

# Way 1
df_grouped = df.groupby('deptid').agg(F.sum('salary').alias('total_sal'))
df_ans = df_grouped.filter(df_grouped.total_sal > 250000)
df_ans.show()
# Out:
# +------+---------+
# |deptid|total_sal|
# +------+---------+
# |    10|   272000|
# +------+---------+

# %%
# Way 2 
df_ans = df.groupby('deptid').agg(F.sum('salary').alias('total_sal')).filter('total_sal > 250000').show()
# Out:
# +------+---------+
# |deptid|total_sal|
# +------+---------+
# |    10|   272000|
# +------+---------+

# %% [markdown]
# # Joins

# %%
df_emp = spark.read.json("emp_details.json")
df_dept = spark.read.json("dept.json")
df_department = spark.read.json("department.json")

df_emp.show()
df_dept.show()
df_department.show()
# Out:
# +---------+------+---+------+
# |     city|deptid|eno|salary|
# +---------+------+---+------+
# |   Mumbai|    10|101| 55000|
# |    Delhi|    20|102| 62000|
# |Bengaluru|    10|103| 58000|
# |Hyderabad|    30|104| 60000|
# |     Pune|    20|105| 49000|
# |  Kolkata|    10|106| 53000|
# |  Chennai|    40|107| 65000|
# |Ahmedabad|    30|108| 61000|
# |   Jaipur|    50|109| 47000|
# |    Surat|    20|110| 56000|
# |   Mumbai|    30|111| 59000|
# |    Delhi|    40|112| 63000|
# |Bengaluru|    10|113| 52000|
# |Hyderabad|    50|114| 61000|
# |  Chennai|    60|115| 66000|
# |     Pune|    30|116| 57000|
# |  Kolkata|    10|117| 54000|
# |   Mumbai|    20|118| 60000|
# |    Delhi|    40|119| 67000|
# |Bengaluru|    50|120| 48000|
# +---------+------+---+------+
#
# +------+--------+
# |deptid|deptname|
# +------+--------+
# |    10| Finance|
# |    20|      HR|
# |    30|      IT|
# |   100|  Travel|
# +------+--------+
#
# +----------+------+
# |  deptname|deptno|
# +----------+------+
# |   Finance|    10|
# |        HR|    20|
# |        IT|    30|
# |Operations|    40|
# | Marketing|    50|
# |     Legal|    70|
# |     Admin|    80|
# +----------+------+

# %% [markdown]
# # Joins with the same columns name in both dataframes

# %%
# Inner join
df_emp.join(df_dept,on='deptid',how='inner').show()
# Out:
# +------+---------+---+------+--------+
# |deptid|     city|eno|salary|deptname|
# +------+---------+---+------+--------+
# |    10|   Mumbai|101| 55000| Finance|
# |    20|    Delhi|102| 62000|      HR|
# |    10|Bengaluru|103| 58000| Finance|
# |    30|Hyderabad|104| 60000|      IT|
# |    20|     Pune|105| 49000|      HR|
# |    10|  Kolkata|106| 53000| Finance|
# |    30|Ahmedabad|108| 61000|      IT|
# |    20|    Surat|110| 56000|      HR|
# |    30|   Mumbai|111| 59000|      IT|
# |    10|Bengaluru|113| 52000| Finance|
# |    30|     Pune|116| 57000|      IT|
# |    10|  Kolkata|117| 54000| Finance|
# |    20|   Mumbai|118| 60000|      HR|
# +------+---------+---+------+--------+

# %%
# left join
df_ans = df_emp.join(df_dept,on='deptid',how='left')
df_ans.orderBy(df_ans.deptname.desc()).show()
# Out:
# +------+---------+---+------+--------+
# |deptid|     city|eno|salary|deptname|
# +------+---------+---+------+--------+
# |    30|Hyderabad|104| 60000|      IT|
# |    30|Ahmedabad|108| 61000|      IT|
# |    30|   Mumbai|111| 59000|      IT|
# |    30|     Pune|116| 57000|      IT|
# |    20|    Delhi|102| 62000|      HR|
# |    20|     Pune|105| 49000|      HR|
# |    20|    Surat|110| 56000|      HR|
# |    20|   Mumbai|118| 60000|      HR|
# |    10|   Mumbai|101| 55000| Finance|
# |    10|Bengaluru|103| 58000| Finance|
# |    10|  Kolkata|106| 53000| Finance|
# |    10|Bengaluru|113| 52000| Finance|
# |    10|  Kolkata|117| 54000| Finance|
# |    40|  Chennai|107| 65000|    NULL|
# |    50|   Jaipur|109| 47000|    NULL|
# |    40|    Delhi|112| 63000|    NULL|
# |    50|Hyderabad|114| 61000|    NULL|
# |    60|  Chennai|115| 66000|    NULL|
# |    40|    Delhi|119| 67000|    NULL|
# |    50|Bengaluru|120| 48000|    NULL|
# +------+---------+---+------+--------+

# %%
# Right join
df_ans = df_emp.join(df_dept,on='deptid',how='right')
df_ans.orderBy(df_ans.deptname.desc()).show()
# Out:
# +------+---------+----+------+--------+
# |deptid|     city| eno|salary|deptname|
# +------+---------+----+------+--------+
# |   100|     NULL|NULL|  NULL|  Travel|
# |    30|     Pune| 116| 57000|      IT|
# |    30|   Mumbai| 111| 59000|      IT|
# |    30|Ahmedabad| 108| 61000|      IT|
# |    30|Hyderabad| 104| 60000|      IT|
# |    20|   Mumbai| 118| 60000|      HR|
# |    20|    Surat| 110| 56000|      HR|
# |    20|     Pune| 105| 49000|      HR|
# |    20|    Delhi| 102| 62000|      HR|
# |    10|  Kolkata| 117| 54000| Finance|
# |    10|Bengaluru| 113| 52000| Finance|
# |    10|  Kolkata| 106| 53000| Finance|
# |    10|Bengaluru| 103| 58000| Finance|
# |    10|   Mumbai| 101| 55000| Finance|
# +------+---------+----+------+--------+

# %%
# Full/outer join
df_ans = df_emp.join(df_dept,on='deptid',how='full')
df_ans.orderBy(df_ans.deptname.desc()).show()
# Out:
# +------+---------+----+------+--------+
# |deptid|     city| eno|salary|deptname|
# +------+---------+----+------+--------+
# |   100|     NULL|NULL|  NULL|  Travel|
# |    30|Hyderabad| 104| 60000|      IT|
# |    30|Ahmedabad| 108| 61000|      IT|
# |    30|   Mumbai| 111| 59000|      IT|
# |    30|     Pune| 116| 57000|      IT|
# |    20|    Delhi| 102| 62000|      HR|
# |    20|     Pune| 105| 49000|      HR|
# |    20|    Surat| 110| 56000|      HR|
# |    20|   Mumbai| 118| 60000|      HR|
# |    10|   Mumbai| 101| 55000| Finance|
# |    10|Bengaluru| 103| 58000| Finance|
# |    10|  Kolkata| 106| 53000| Finance|
# |    10|Bengaluru| 113| 52000| Finance|
# |    10|  Kolkata| 117| 54000| Finance|
# |    40|  Chennai| 107| 65000|    NULL|
# |    40|    Delhi| 112| 63000|    NULL|
# |    40|    Delhi| 119| 67000|    NULL|
# |    50|   Jaipur| 109| 47000|    NULL|
# |    50|Hyderabad| 114| 61000|    NULL|
# |    50|Bengaluru| 120| 48000|    NULL|
# +------+---------+----+------+--------+
# only showing top 20 rows

# %%
# Left semi join
df_emp.join(df_dept,on='deptid',how='left_semi').show()
# Out:
# +------+---------+---+------+
# |deptid|     city|eno|salary|
# +------+---------+---+------+
# |    10|   Mumbai|101| 55000|
# |    20|    Delhi|102| 62000|
# |    10|Bengaluru|103| 58000|
# |    30|Hyderabad|104| 60000|
# |    20|     Pune|105| 49000|
# |    10|  Kolkata|106| 53000|
# |    30|Ahmedabad|108| 61000|
# |    20|    Surat|110| 56000|
# |    30|   Mumbai|111| 59000|
# |    10|Bengaluru|113| 52000|
# |    30|     Pune|116| 57000|
# |    10|  Kolkata|117| 54000|
# |    20|   Mumbai|118| 60000|
# +------+---------+---+------+

# %%
# Left anti join
df_emp.join(df_dept,on='deptid',how='left_anti').show()
# Out:
# +------+---------+---+------+
# |deptid|     city|eno|salary|
# +------+---------+---+------+
# |    40|  Chennai|107| 65000|
# |    50|   Jaipur|109| 47000|
# |    40|    Delhi|112| 63000|
# |    50|Hyderabad|114| 61000|
# |    60|  Chennai|115| 66000|
# |    40|    Delhi|119| 67000|
# |    50|Bengaluru|120| 48000|
# +------+---------+---+------+

# %% [markdown]
# # Joins when both data framews having different common column name

# %%
# Inner join
df_emp.join(df_department,on=df_emp.deptid == df_department.deptno,how='inner').show()
# or

df_emp.join(df_department,df_emp.deptid == df_department.deptno,'inner').show()
# Out:
# +---------+------+---+------+----------+------+
# |     city|deptid|eno|salary|  deptname|deptno|
# +---------+------+---+------+----------+------+
# |   Mumbai|    10|101| 55000|   Finance|    10|
# |    Delhi|    20|102| 62000|        HR|    20|
# |Bengaluru|    10|103| 58000|   Finance|    10|
# |Hyderabad|    30|104| 60000|        IT|    30|
# |     Pune|    20|105| 49000|        HR|    20|
# |  Kolkata|    10|106| 53000|   Finance|    10|
# |  Chennai|    40|107| 65000|Operations|    40|
# |Ahmedabad|    30|108| 61000|        IT|    30|
# |   Jaipur|    50|109| 47000| Marketing|    50|
# |    Surat|    20|110| 56000|        HR|    20|
# |   Mumbai|    30|111| 59000|        IT|    30|
# |    Delhi|    40|112| 63000|Operations|    40|
# |Bengaluru|    10|113| 52000|   Finance|    10|
# |Hyderabad|    50|114| 61000| Marketing|    50|
# |     Pune|    30|116| 57000|        IT|    30|
# |  Kolkata|    10|117| 54000|   Finance|    10|
# |   Mumbai|    20|118| 60000|        HR|    20|
# |    Delhi|    40|119| 67000|Operations|    40|
# |Bengaluru|    50|120| 48000| Marketing|    50|
# +---------+------+---+------+----------+------+
#
# +---------+------+---+------+----------+------+
# |     city|deptid|eno|salary|  deptname|deptno|
# +---------+------+---+------+----------+------+
# |   Mumbai|    10|101| 55000|   Finance|    10|
# |    Delhi|    20|102| 62000|        HR|    20|
# |Bengaluru|    10|103| 58000|   Finance|    10|
# |Hyderabad|    30|104| 60000|        IT|    30|
# |     Pune|    20|105| 49000|        HR|    20|
# |  Kolkata|    10|106| 53000|   Finance|    10|
# |  Chennai|    40|107| 65000|Operations|    40|
# |Ahmedabad|    30|108| 61000|        IT|    30|
# |   Jaipur|    50|109| 47000| Marketing|    50|
# |    Surat|    20|110| 56000|        HR|    20|
# |   Mumbai|    30|111| 59000|        IT|    30|
# |    Delhi|    40|112| 63000|Operations|    40|
# |Bengaluru|    10|113| 52000|   Finance|    10|
# |Hyderabad|    50|114| 61000| Marketing|    50|
# |     Pune|    30|116| 57000|        IT|    30|
# |  Kolkata|    10|117| 54000|   Finance|    10|
# |   Mumbai|    20|118| 60000|        HR|    20|
# |    Delhi|    40|119| 67000|Operations|    40|
# |Bengaluru|    50|120| 48000| Marketing|    50|
# +---------+------+---+------+----------+------+

# %% [markdown]
# # complete for all other joins

# %%
df1 = spark.read.csv("emp1.csv",header=True)
df2 = spark.read.csv("emp2.csv",header=True)
df1.show()
# Out:
# +------+---+
# | ename|eno|
# +------+---+
# |  Amar|  1|
# | Akash|  2|
# |Pankaj|  3|
# | Saran|  4|
# |Mangal|  5|
# +------+---+

# %%
df1.unionByName(df2).show()
df2.unionByName(df1).show()
# Out:
# +------+---+
# | ename|eno|
# +------+---+
# |  Amar|  1|
# | Akash|  2|
# |Pankaj|  3|
# | Saran|  4|
# |Mangal|  5|
# |Mahesh|  6|
# |Rakesh|  7|
# |Charan|  8|
# | Saran|  4|
# |Mangal|  5|
# +------+---+
#
# +---+------+
# |eno| ename|
# +---+------+
# |  6|Mahesh|
# |  7|Rakesh|
# |  8|Charan|
# |  4| Saran|
# |  5|Mangal|
# |  1|  Amar|
# |  2| Akash|
# |  3|Pankaj|
# |  4| Saran|
# |  5|Mangal|
# +---+------+

# %%
df1.union(df2).show()
df1.unionAll(df2).show()
# Out:
# +------+------+
# | ename|   eno|
# +------+------+
# |  Amar|     1|
# | Akash|     2|
# |Pankaj|     3|
# | Saran|     4|
# |Mangal|     5|
# |     6|Mahesh|
# |     7|Rakesh|
# |     8|Charan|
# |     4| Saran|
# |     5|Mangal|
# +------+------+
#
# +------+------+
# | ename|   eno|
# +------+------+
# |  Amar|     1|
# | Akash|     2|
# |Pankaj|     3|
# | Saran|     4|
# |Mangal|     5|
# |     6|Mahesh|
# |     7|Rakesh|
# |     8|Charan|
# |     4| Saran|
# |     5|Mangal|
# +------+------+

# %%
df1.union(df2).show()
# Out:
# +---+------+
# |eno| ename|
# +---+------+
# |  1|  Amar|
# |  2| Akash|
# |  3|Pankaj|
# |  4| Saran|
# |  5|Mangal|
# |  6|Mahesh|
# |  7|Rakesh|
# |  8|Charan|
# |  4| Saran|
# |  5|Mangal|
# +---+------+

# %%
df1.unionByName(df2).show()
# Out:
# +---+------+
# |eno| ename|
# +---+------+
# |  1|  Amar|
# |  2| Akash|
# |  3|Pankaj|
# |  4| Saran|
# |  5|Mangal|
# |  6|Mahesh|
# |  7|Rakesh|
# |  8|Charan|
# |  4| Saran|
# |  5|Mangal|
# +---+------+

# %%
spark = SparkSession.builder.appName("DB Connections").config("spark.jars.packages", "mysql:mysql-connector-java:8.0.33").config("spark.jars", "C:/Users/hetur/Downloads/ojdbc17.jar").getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 spark = SparkSession.builder.appName("DB Connections").config("spark.jars.packages", "mysql:mysql-connector-java:8.0.33").config("spark.jars", "C:/Users/hetur/Downloads/ojdbc17.jar").getOrCreate()
#
# File C:\Python310\lib\site-packages\pyspark\sql\session.py:561, in SparkSession.Builder.getOrCreate(self)
#     559     session = SparkSession(sc, options=self._options)
#     560 else:
# --> 561     module = SparkSession._get_j_spark_session_module(session._jvm)
#     562     module.applyModifiableSettings(session._jsparkSession, self._options)
#     563 return session
#
# File C:\Python310\lib\site-packages\pyspark\sql\session.py:672, in SparkSession._get_j_spark_session_module(jvm)
#     670 @staticmethod
#     671 def _get_j_spark_session_module(jvm: "JVMView") -> "JavaObject":
# --> 672     return getattr(getattr(jvm, "org.apache.spark.sql.classic.SparkSession$"), "MODULE$")
#
# File C:\Python310\lib\site-packages\py4j\java_gateway.py:1752, in JVMView.__getattr__(self, name)
#    1749 if name == UserHelpAutoCompletion.KEY:
#    1750     return UserHelpAutoCompletion()
# -> 1752 answer = self._gateway_client.send_command(
#    1753     proto.REFLECTION_COMMAND_NAME +
#    1754     proto.REFL_GET_UNKNOWN_SUB_COMMAND_NAME + name + "\n" + self._id +
#    1755     "\n" + proto.END_COMMAND_PART)
#    1756 if answer == proto.SUCCESS_PACKAGE:
#    1757     return JavaPackage(name, self._gateway_client, jvm_id=self._id)
#
# File C:\Python310\lib\site-packages\py4j\java_gateway.py:1036, in GatewayClient.send_command(self, command, retry, binary)
#    1015 def send_command(self, command, retry=True, binary=False):
#    1016     """Sends a command to the JVM. This method is not intended to be
#    1017        called directly by Py4J users. It is usually called by
#    1018        :class:`JavaMember` instances.
#    (...)
#    1034      if `binary` is `True`.
#    1035     """
# -> 1036     connection = self._get_connection()
#    1037     try:
#    1038         response = connection.send_command(command)
#
# File C:\Python310\lib\site-packages\py4j\clientserver.py:284, in JavaClient._get_connection(self)
#     281     pass
#     283 if connection is None or connection.socket is None:
# --> 284     connection = self._create_new_connection()
#     285 return connection
#
# File C:\Python310\lib\site-packages\py4j\clientserver.py:291, in JavaClient._create_new_connection(self)
#     287 def _create_new_connection(self):
#     288     connection = ClientServerConnection(
#     289         self.java_parameters, self.python_parameters,
#     290         self.gateway_property, self)
# --> 291     connection.connect_to_java_server()
#     292     self.set_thread_connection(connection)
#     293     return connection
#
# File C:\Python310\lib\site-packages\py4j\clientserver.py:438, in ClientServerConnection.connect_to_java_server(self)
#     435 if self.ssl_context:
#     436     self.socket = self.ssl_context.wrap_socket(
#     437         self.socket, server_hostname=self.java_address)
# --> 438 self.socket.connect((self.java_address, self.java_port))
#     439 self.stream = self.socket.makefile("rb")
#     440 self.is_connected = True
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Test Spark") \
    .getOrCreate()

print("✅ Spark started successfully!")
print("Spark version:", spark.version)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Input In [27], in <cell line: 3>()
#       1 from pyspark.sql import SparkSession
#       3 spark = SparkSession.builder \
#       4     .appName("Test Spark") \
# ----> 5     .getOrCreate()
#       7 print("✅ Spark started successfully!")
#       8 print("Spark version:", spark.version)
#
# File C:\Python310\lib\site-packages\pyspark\sql\session.py:561, in SparkSession.Builder.getOrCreate(self)
#     559     session = SparkSession(sc, options=self._options)
#     560 else:
# --> 561     module = SparkSession._get_j_spark_session_module(session._jvm)
#     562     module.applyModifiableSettings(session._jsparkSession, self._options)
#     563 return session
#
# File C:\Python310\lib\site-packages\pyspark\sql\session.py:672, in SparkSession._get_j_spark_session_module(jvm)
#     670 @staticmethod
#     671 def _get_j_spark_session_module(jvm: "JVMView") -> "JavaObject":
# --> 672     return getattr(getattr(jvm, "org.apache.spark.sql.classic.SparkSession$"), "MODULE$")
#
# File C:\Python310\lib\site-packages\py4j\java_gateway.py:1752, in JVMView.__getattr__(self, name)
#    1749 if name == UserHelpAutoCompletion.KEY:
#    1750     return UserHelpAutoCompletion()
# -> 1752 answer = self._gateway_client.send_command(
#    1753     proto.REFLECTION_COMMAND_NAME +
#    1754     proto.REFL_GET_UNKNOWN_SUB_COMMAND_NAME + name + "\n" + self._id +
#    1755     "\n" + proto.END_COMMAND_PART)
#    1756 if answer == proto.SUCCESS_PACKAGE:
#    1757     return JavaPackage(name, self._gateway_client, jvm_id=self._id)
#
# File C:\Python310\lib\site-packages\py4j\java_gateway.py:1036, in GatewayClient.send_command(self, command, retry, binary)
#    1015 def send_command(self, command, retry=True, binary=False):
#    1016     """Sends a command to the JVM. This method is not intended to be
#    1017        called directly by Py4J users. It is usually called by
#    1018        :class:`JavaMember` instances.
#    (...)
#    1034      if `binary` is `True`.
#    1035     """
# -> 1036     connection = self._get_connection()
#    1037     try:
#    1038         response = connection.send_command(command)
#
# File C:\Python310\lib\site-packages\py4j\clientserver.py:284, in JavaClient._get_connection(self)
#     281     pass
#     283 if connection is None or connection.socket is None:
# --> 284     connection = self._create_new_connection()
#     285 return connection
#
# File C:\Python310\lib\site-packages\py4j\clientserver.py:291, in JavaClient._create_new_connection(self)
#     287 def _create_new_connection(self):
#     288     connection = ClientServerConnection(
#     289         self.java_parameters, self.python_parameters,
#     290         self.gateway_property, self)
# --> 291     connection.connect_to_java_server()
#     292     self.set_thread_connection(connection)
#     293     return connection
#
# File C:\Python310\lib\site-packages\py4j\clientserver.py:438, in ClientServerConnection.connect_to_java_server(self)
#     435 if self.ssl_context:
#     436     self.socket = self.ssl_context.wrap_socket(
#     437         self.socket, server_hostname=self.java_address)
# --> 438 self.socket.connect((self.java_address, self.java_port))
#     439 self.stream = self.socket.makefile("rb")
#     440 self.is_connected = True
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
